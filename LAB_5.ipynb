  1.28933804, 2.44961149, 2.59890411, 0.99852354, 1.6011047 , 1.39715846,
  1.15113972, 2.15581772,10.16069227,10.09925781, 8.86636677, 9.50456317,
  9.23543672, 9.1076031 , 9.97230484, 8.20321016, 8.82690516, 9.35457243,
  7.91303165,12.62426638, 8.81541695,10.3498697 , 9.43819067, 8.23982127,
  7.51664999, 7.28263021, 8.95260897, 8.13140226, 8.58830687, 8.12360175,
  9.08539736,10.19696193,10.14229026,11.77892769, 9.71575359, 8.94748796,
  9.58875061,11.24755423,10.08946357, 8.34796562, 9.38047403, 6.42393316,
 10.0377009 , 9.15064103, 8.94697073,16.67972784,18.98052593,16.0165759 ,
 17.42647456,16.23718297,16.44495458,17.54160216,16.8258439 ,17.39313276,
 19.92254302,19.68655888,15.7791983 ,15.15889596,17.04800081,12.43306416,
 17.03548912,19.02719451,18.27845253,18.56968976,16.68867802,15.46598445,
 19.33997113,18.89823321,18.4612881 ,15.40804498,16.10411805,17.47965598,
 15.64640795,15.92280707,18.04628584,18.45625883,16.72884818,18.54988649,
 18.57630941,17.76078486,17.53624688,16.42743673],
 "class":['Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1',
'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1',
'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1',
'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2',
'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2',
'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2',
'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group3', 'Group3',
'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3',
'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3',
'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3',
'Group3', 'Group3', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4',
'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4',
'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4',
'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4'] }

# %%
pd.DataFrame(data).to_csv("data.csv")

# %%
pd.DataFrame(data).head(10)
# Out:
#           X         Y   class
# 0  3.711316  6.148990  Group1
# 1  2.740616  5.795332  Group1
# 2  2.648958  5.340273  Group1
# 3  2.989421  5.397712  Group1
# 4  1.072474  5.788024  Group1
# 5  0.642798  5.115100  Group1
# 6  2.467772  5.898960  Group1
# 7  2.231436  6.486948  Group1
# 8  0.644119  5.988981  Group1
# 9  0.645485  5.863802  Group1

# %%
X = np.c_[data["X"], data["Y"]]

# %%
# Выполняется min-max нормализация данных - преобразование значений в диапазон [0, 1]
xmin = np.min(X)
# Делим сдвинутые значения на диапазон, по итогу имеем значения [0, 1]
Xnorm = (X - xmin) / (np.max(X) - xmin)

# %%
# OneHotEncoder - класс для преобразования категориальных признаков в бинарный формат

from sklearn.preprocessing import OneHotEncoder
# sparse_output = False возвращает обычный массив вместо разреженной матрицы
ohe = OneHotEncoder(sparse_output = False)
Yenc = ohe.fit_transform(np.array(data["class"]).reshape(-1,1) )

# %%
# Проверка размерностей входных и выходных данных

# Возвращает размерность массива нормализованных входных данных
print(f"Форма тензора X: {Xnorm.shape}")
# Вовзращает форму массива one-hot закодированных выходных данных
print(f"Форма тензора Y: {Yenc.shape}")
# Out:
# Форма тензора X: (148, 2)
# Форма тензора Y: (148, 4)

# %%
# Разделение входных и выходныех данных на обучающую и тестовую выборки
from sklearn.model_selection import train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(Xnorm, Yenc, test_size = 0.25)
print(f"Форма тензора Xtrain: {xTrain.shape}")
print(f"Форма тензора Ytrain: {yTrain.shape}")
print(f"Форма тензора Xtest: {xTest.shape}")
print(f"Форма тензора Ytest: {yTest.shape}")
# Out:
# Форма тензора Xtrain: (111, 2)
# Форма тензора Ytrain: (111, 4)
# Форма тензора Xtest: (37, 2)
# Форма тензора Ytest: (37, 4)

# %%
# Построение нейронной сети для многоклассовой классификации с помощью Tensorflow
from keras.models import Sequential
from keras.layers import Dense
model = Sequential( [

# Первый скрытый слой
# 4 нейрона, функция активации ReLU, на вход 2 признака (как у моих данных)
Dense( units = 4, activation = "relu", input_shape = (2,) ),

# Второй скрытый слой
# Также 4 нейронга с ReLU, размерность определяетяс автоматически
Dense( units = 4, activation = "relu"),

# Выходной слой
# 4 нейрона по одному на каждый класс, sigmoid преобразует числа в диапазон от 0 до 1
Dense( units = yTrain.shape[1], activation = "sigmoid" )
] )

# optimizer = "adam" - алгоритм отпимизации для обучения
# loss="categorical_crossentropy" - функция потерь для многоклассовой классификации
# metrics=["categorical_accuracy"] - метрика для оценки точности
model.compile(optimizer = "adam", loss = "categorical_crossentropy", metrics = ["categorical_accuracy"] )
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 4)              │            12 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 4)              │            20 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 4)              │            20 │
# ...

# %%
# Обучение нейронной сети
hist = model.fit( x = xTrain, y = yTrain, epochs = 80, batch_size = 10 )
import matplotlib.pyplot as plt
plt.plot(hist.history["loss"], label = "Loss")
plt.plot(hist.history["categorical_accuracy"], label = "accuracy")
plt.ylabel("Loss/Accuracy")
plt.xlabel("Epochs")
plt.legend()
plt.show()
# Out:
# Epoch 1/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.2634 - loss: 1.3283
# Epoch 2/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.2549 - loss: 1.3250
# Epoch 3/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.2762 - loss: 1.3013
# Epoch 4/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.3319 - loss: 1.2810
# Epoch 5/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.3354 - loss: 1.3182
# Epoch 6/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.2791 - loss: 1.2838
# Epoch 7/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.3052 - loss: 1.2874
# Epoch 8/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4779 - loss: 1.2321
# Epoch 9/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.5353 - loss: 1.2405
# Epoch 10/80
# ...

# %%
# Оценка модели на тестовой выборке
model.evaluate( xTest, yTest )

# Отработала вся тестовая выборка 2/2
# 0s 24ms/step время обработки одного шага
# Точность 100%
# loss: 0.6387 значение функции потерь
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 1.0000 - loss: 0.6387
# [0.6320458054542542, 1.0]

# %%
# Пройдем каждый пример тестовой выборки отдельно:
match = 0
for i in range(len(xTest)):
  x = xTest[i]
  y = yTest[i]
 # Для подачи вектора на вход нейросети, его необходимо преобразовать к
 # двумерному тензору формата (1 строка, n столбцов)
  yPred = model.predict( x.reshape(1,-1) )
 # На выходе yPred также представляет собой двумерный объект
    # Из одной строки - вектора логитов - выходов сигмоид
    # Нам нужно выбрать максимальный из них
  maxLogit = np.argmax(yPred)
 # Этот индекс - номер группы объекта, но точно лучше узнать в нашем
    # OneHotEncoder'е - без обратного преоразования можно их посмотреть в массиве categories_
    # номера соответствуют порядку категорий в нем
    # Фактическое значение категории (на самом деле которое нам известно - из тестовой выборки)
  yAct = np.argmax(y)
  if maxLogit == yAct:
      match += 1
  print(f"Распознали как группу {ohe.categories_[0][maxLogit]} на самом деле: {ohe.categories_[0][yAct]}" )
print(f"Верно распознано {match} из {len(xTest)}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Распознали как группу Group1 на самом деле: Group1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Распознали как группу Group2 на самом деле: Group2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Распознали как группу Group2 на самом деле: Group2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Распознали как группу Group2 на самом деле: Group2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Распознали как группу Group4 на самом деле: Group4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Распознали как группу Group3 на самом деле: Group3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Распознали как группу Group2 на самом деле: Group2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Распознали как группу Group1 на самом деле: Group1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Распознали как группу Group2 на самом деле: Group2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Распознали как группу Group1 на самом деле: Group1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# ...
